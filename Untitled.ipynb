# %%
import torch
import hw2_utils as utils
import hw2

# %%
hw2.logistic_vs_ols()

# %%
w = hw2.linear_normal(X,Y)

# %%
x = torch.rand(14,2)

# %%
X.shape

# %%
x.shape

# %%
a = torch.tensor([[1,2,3],[4,5,6]])

# %%
a.shape

# %%
b = a.T

# %%
b

# %%
b.shape

# %%
torch.matmul(a, b)

# %%
torch.ones(1,1)

# %%
g = torch.cat((torch.ones(X.shape[0], 1), X),1)

# %%
g.shape

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X, torch.cat((torch.ones(X.shape[0], 1), X), 1)@w, color="red")
plt.xlabel("data points")
plt.ylabel("target values")
plt.title("Linear Regression")
plt.scatter(X,Y)
plt.show()
p = plt.gcf()

# %%
X, Y = utils.load_logistic_data()

# %%
X.shape

# %%
type(p)

# %%
Y.shape

# %%
X.shape

# %%
hw2.logistic_vs_ols()
